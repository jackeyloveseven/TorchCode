# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/17_dropout.ipynb)
#
# # 🟢 简单：实现 Dropout
#
# 从零实现 **Dropout** 正则化。
#
# ### 函数签名
# ```python
# class MyDropout(nn.Module):
#     def __init__(self, p: float = 0.5): ...
#     def forward(self, x: Tensor) -> Tensor: ...
# ```
#
# ### 规则
# - **训练**时：以概率 `p` 将每个元素置零，并将剩余元素缩放 `1/(1-p)`
# - **推理**时：直接返回输入（恒等映射）
# - 不得使用 `nn.Dropout` 或 `F.dropout`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn as nn

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class MyDropout(nn.Module):
    def __init__(self, p=0.5):
        super().__init__()
        pass

    def forward(self, x):
        pass

# %%
# 🧪 Debug
d = MyDropout(p=0.5)
d.train()
x = torch.ones(10)
print('Train:', d(x))
d.eval()
print('Eval: ', d(x))

# %%
# ✅ SUBMIT
from torch_judge import check
check('dropout')
