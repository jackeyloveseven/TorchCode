# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/11_sliding_window.ipynb)
#
# # 🔴 困难：滑动窗口注意力
#
# 实现**滑动窗口注意力（Sliding Window Attention）**——Longformer、Mistral 等模型中用于高效处理长上下文的技术。
#
# 每个位置 $i$ 只能关注满足 $|i - j| \le w$（窗口大小）的位置 $j$。
#
# ### 函数签名
# ```python
# def sliding_window_attention(Q, K, V, window_size):
#     # Q, K, V: (batch, seq, d) → 输出: (batch, seq, d_v)
#     # window_size: int — 位置 i 关注 [i-w, i+w]
# ```
#
# ### 规则
# - **不得**使用稀疏注意力库
# - 对窗口外的位置掩码为 `-inf`
# - `window_size=0`：仅自注意力——输出应等于 V
# - `window_size >= seq_len`：等价于全注意力

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def sliding_window_attention(Q, K, V, window_size):
    pass  # Replace this

# %%
# 🧪 Debug
Q = torch.randn(1, 6, 8)
K = torch.randn(1, 6, 8)
V = torch.randn(1, 6, 8)

out = sliding_window_attention(Q, K, V, window_size=1)
print("Output shape:", out.shape)  # (1, 6, 8)

# window=0 should return V
out0 = sliding_window_attention(Q, K, V, window_size=0)
print("window=0 == V?", torch.allclose(out0, V, atol=1e-5))

# %%
from torch_judge import check
check('sliding_window')
